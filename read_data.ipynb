# %%
import argparse, glob, json, os, re
import pandas as pd

# %%
df = pd.read_json("kz_config_20260511.json")

print(df.head())
# Out:
#                                                            meta  \
# snapshotDate                                           20260511
# extractedAt                         2026-05-12T07:27:20.525114Z
# groups        [96g1, 96g2, bdk1, blg1, brkzg1, cokzg1, egkzg...
# phk1                                                        NaN
# pkk1                                                        NaN
#
#                                                         summary  \
# snapshotDate                                                NaN
# extractedAt                                                 NaN
# groups                                                      NaN
# phk1          {'providers': {'total': 128, 'active': 32, 'in...
# pkk1          {'providers': {'total': 130, 'active': 13, 'in...
#
#                                                accountVariables  \
# snapshotDate                                                NaN
# ...

# %%
df.keys()
# Out:
# Index(['meta', 'summary', 'accountVariables', 'fundingProviders',
#        'fundingMethods'],
#       dtype='str')
